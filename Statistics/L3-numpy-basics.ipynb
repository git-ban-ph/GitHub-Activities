# %% [markdown]
# # Numpy Basics <hr style="border: 2.5px solid; color: #d020b0ff"></hr>

# %% [markdown]
# <b>Axel Nazir M. Belnas</b>
# <br>3rd year</br>

# %%
# imports and packages
import numpy as np
from scipy import stats
from statistics import multimode

# %% [markdown]
# # 1D Array

# %%
my_array = np.array([1, 2, 3])
my_array
# Out:
# array([1, 2, 3])

# %%
np.shape(my_array)
# Out:
# (3,)

# %% [markdown]
# # 2D Array

# %%
my_array = np.array([
    [1, 2, 3], [4, 5, 6]
    ])
my_array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.shape(my_array)
# Out:
# (2, 3)

# %%
t_array = my_array.T
t_array
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
np.shape(t_array)
# Out:
# (3, 2)

# %% [markdown]
# # Measures of Central Tedency

# %%
# Jaguar vs Panther

resistance = np.array([[10.6, 9.1, 9.3, 9.8, 10.5, 10.4, 9.5, 11, 10.4, 3, 9.8],
                       [10.1, 11, 9.1, 20, 9.2, 10.8, 9.9, 9.2, 9.1, 9.1, np.nan]
                      ])
resistance
# Out:
# array([[10.6,  9.1,  9.3,  9.8, 10.5, 10.4,  9.5, 11. , 10.4,  3. ,  9.8],
#        [10.1, 11. ,  9.1, 20. ,  9.2, 10.8,  9.9,  9.2,  9.1,  9.1,  nan]])

# %%
np.shape(resistance)
# Out:
# (2, 11)

# %%
res_mean = np.nanmean(resistance,axis=1)
res_mean
# Out:
# array([ 9.4 , 10.75])

# %%
print(res_mean)
print("Jaguar Mean: " + str(res_mean[0].round(2)))
print("Panther Mean: " + str(res_mean[1].round(2)))
# Out:
# [ 9.4  10.75]
# Jaguar Mean: 9.4
# Panther Mean: 10.75

# %%
print(f'Jaguar:{res_mean[0]:.2f} ohms')
print(f'Panther:{res_mean[1]:.2f} ohms')
# Out:
# Jaguar:9.40 ohms
# Panther:10.75 ohms

# %%
# Median

res_median = np.nanmedian(resistance,axis=1)
res_median
# Out:
# array([9.8 , 9.55])

# %%
print(f'Jaguar:{res_median[0]:.2f} ohms')
print(f'Panther:{res_median[1]:.2f} ohms')
# Out:
# Jaguar:9.80 ohms
# Panther:9.55 ohms

# %%
res_mode = stats.mode(resistance,axis=1)
res_mode
# Out:
# ModeResult(mode=array([9.8, 9.1]), count=array([2, 3]))

# %%
jag_res = resistance[0]

print("Jaguar Mode: ")
for i in multimode(jag_res):
    print(f'{i} ohms')
# Out:
# Jaguar Mode:
# 9.8 ohms
# 10.4 ohms

# %%
pan_res = resistance[1]

print("Panther Mode: ")
for i in multimode(pan_res):
    print(f'{i} ohms')
# Out:
# Panther Mode:
# 9.1 ohms

# %% [markdown]
# # Measures in Variability

# %%
resistance = np.array([[10.6, 9.1, 9.3, 9.8, 10.5, 10.4, 9.5, 11, 10.4, 3, 9.8],
                       [10.1, 11, 9.1, 20, 9.2, 10.8, 9.9, 9.2, 9.1, 9.1, np.nan]
                      ])
resistance
# Out:
# array([[10.6,  9.1,  9.3,  9.8, 10.5, 10.4,  9.5, 11. , 10.4,  3. ,  9.8],
#        [10.1, 11. ,  9.1, 20. ,  9.2, 10.8,  9.9,  9.2,  9.1,  9.1,  nan]])

# %%
# Range

res_max = np.nanmax(resistance, axis=1)
res_min = np.nanmin(resistance, axis=1)


res_range = res_max-res_min
res_range
# Out:
# array([ 8. , 10.9])

# %%
print(f'Jaguar range:{res_range[0]:.2f} ohms')
print(f'Panther range:{res_range[1]:.2f} ohms')
# Out:
# Jaguar range:8.00 ohms
# Panther range:10.90 ohms

# %%
# IQR

res_Q1 = np.nanpercentile(resistance, 25, axis=1)
res_Q1.round(2)
# Out:
# array([9.4 , 9.12])

# %%
res_Q3 = np.nanpercentile(resistance, 75, axis=1)
res_Q3.round(2)
# Out:
# array([10.45, 10.62])

# %%
print(f'Jaguar IQR: {res_Q3[0]-res_Q1[0]:.2f} ohms')
print(f'Panther IQR: {res_Q3[1]-res_Q1[1]:.2f} ohms')
# Out:
# Jaguar IQR: 1.05 ohms
# Panther IQR: 1.50 ohms

# %%
res_var = np.nanvar(resistance, ddof=1, axis=1).round(2)
res_var
# Out:
# array([ 4.86, 11.08])

# %%
print(f'Jaguar Variance: {res_var[0]:.2f} ohms')
print(f'Panther Variance: {res_var[1]:.2f} ohms')
# Out:
# Jaguar Variance: 4.86 ohms
# Panther Variance: 11.08 ohms

# %%
res_std = np.nanstd(resistance, ddof=1, axis=1).round(2)
res_std
# Out:
# array([2.2 , 3.33])

# %%
print(f'Jaguar STD: {res_std[0]:.2f} ohms')
print(f'Panther STD: {res_std[1]:.2f} ohms')
# Out:
# Jaguar STD: 2.20 ohms
# Panther STD: 3.33 ohms
